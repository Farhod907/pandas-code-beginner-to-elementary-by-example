# %%
import pandas as pd

# %% [markdown]
# # series in pandas

# %%
series = pd.Series(["BMW", "Mers", "Bugatti"])
series
# Out:
# 0        BMW
# 1       Mers
# 2    Bugatti
# dtype: object

# %%
colour  = pd.Series(['red', 'blue', "green"])
colour
# Out:
# 0      red
# 1     blue
# 2    green
# dtype: object

# %%
car_data = pd.DataFrame({"car make": series, "colour":colour})
car_data
# Out:
#   car make colour
# 0      BMW    red
# 1     Mers   blue
# 2  Bugatti  green

# %% [markdown]
# # import data

# %%
# heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")
# heart_disease.to_csv("big.csv", index=False)

# %%
file = pd.read_csv('big.csv')
file
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# # descripe Data

# %%
file.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
file.mean()
# Out:
# age          54.366337
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# dtype: float64

# %%
file["age"].sum()
# Out:
# 16473

# %%
len(file)
# Out:
# 303

# %%
file.head(7)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
file.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
animals = pd.Series(['cat', 'bat','rat', 'dog', 'pandas'], index =[1,3,4,5,1])
animals
# Out:
# 1       cat
# 3       bat
# 4       rat
# 5       dog
# 1    pandas
# dtype: object

# %%
animals.loc[1]
# Out:
# 1       cat
# 1    pandas
# dtype: object

# %%
file.loc[:5]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1

# %%
animals
# Out:
# 1       cat
# 3       bat
# 4       rat
# 5       dog
# 1    pandas
# dtype: object

# %%
animals.loc[:3]
# Out:
# 1    cat
# 3    bat
# dtype: object

# %%
file.age
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
file[file['sex'] == 1]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 3     56    1   1       120   236    0        1      178      0      0.8
# 5     57    1   0       140   192    0        1      148      0      0.4
# 7     44    1   1       120   263    0        1      173      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 295   63    1   0       140   187    0        0      144      1      4.0
# 297   59    1   0       164   176    1        0       90      0      1.0
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
file
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
file.groupby(['age']).mean()
# Out:
#           sex        cp    trestbps        chol       fbs   restecg  \
# age
# 29   1.000000  1.000000  130.000000  204.000000  0.000000  0.000000
# 34   0.500000  2.000000  118.000000  196.000000  0.000000  0.500000
# 35   0.750000  0.250000  126.500000  213.750000  0.000000  0.750000
# 37   0.500000  2.000000  125.000000  232.500000  0.000000  1.000000
# 38   1.000000  2.333333  132.000000  193.666667  0.000000  1.000000
# 39   0.500000  1.500000  122.500000  239.750000  0.000000  0.750000
# 40   1.000000  1.000000  134.000000  196.333333  0.000000  0.666667
# 41   0.600000  1.200000  119.000000  220.700000  0.000000  0.600000
# 42   0.750000  1.250000  127.000000  246.750000  0.125000  0.750000
# 43   0.750000  0.500000  126.375000  256.750000  0.250000  0.625000
# 44   0.818182  1.181818  120.727273  221.363636  0.000000  0.636364
# 45   0.625000  0.750000  122.375000  247.375000  0.000000  0.250000
# 46   0.571429  0.857143  128.000000  230.285714  0.142857  0.571429
# ...

# %%
# %matplotlib inline
import matplotlib.plot as plt

# %%
file["age"].chart()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [78], in <cell line: 1>()
# ----> 1 file["age"].chart()
#
# File ~\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'chart'

# %%
car_info = pd.read_csv('car-sales.csv')
car_info
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_info['Price'] = car_info["Price"].apply(str).str.replace('[\$\,\.]', '').astype(int)
# Out:
# C:\Users\student.ASTRUM-DOMAIN\AppData\Local\Temp\ipykernel_13244\3292331666.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_info['Price'] = car_info["Price"].apply(str).str.replace('[\$\,\.]', '').astype(int)

# %%
car_info
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_info['Price'].plot()
# Out:
# <AxesSubplot:>

# %%
car_info["Make"] = car_info["Make"].str.lower()

# %%
car_info
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_missing = pd.read_csv('car-sales-missing-data.csv')
car_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_missing.dropna(inplace=True)
car_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_missing.to_csv('car_missing_dropped.csv' )
# car_missing.to_excel('car_missing_dropped_excel.csv')

# %%
seats = pd.Series([2,3,4,2,3])
car_info['Seats'] = seats
car_info
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    2.0
# 1   honda    Red          87899      4   500000    3.0
# 2  toyota   Blue          32549      3   700000    4.0
# 3     bmw  Black          11179      5  2200000    2.0
# 4  nissan  White         213095      4   350000    3.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_info
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_info['Seats'].fillna(4, inplace=True)
car_info
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    2.0
# 1   honda    Red          87899      4   500000    3.0
# 2  toyota   Blue          32549      3   700000    4.0
# 3     bmw  Black          11179      5  2200000    2.0
# 4  nissan  White         213095      4   350000    3.0
# 5  toyota  Green          99213      4   450000    4.0
# 6   honda   Blue          45698      4   750000    4.0
# 7   honda   Blue          54738      4   700000    4.0
# 8  toyota  White          60000      4   625000    4.0
# 9  nissan  White          31600      4   970000    4.0

# %%
fuel = [5.7,5.3,4.2,4.5,5.6,5.4,4.9,6.8,4.7,7.3]
car_info["Fuel"] = fuel
car_info
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel
# 0  toyota  White         150043      4   400000    2.0   5.7
# 1   honda    Red          87899      4   500000    3.0   5.3
# 2  toyota   Blue          32549      3   700000    4.0   4.2
# 3     bmw  Black          11179      5  2200000    2.0   4.5
# 4  nissan  White         213095      4   350000    3.0   5.6
# 5  toyota  Green          99213      4   450000    4.0   5.4
# 6   honda   Blue          45698      4   750000    4.0   4.9
# 7   honda   Blue          54738      4   700000    4.0   6.8
# 8  toyota  White          60000      4   625000    4.0   4.7
# 9  nissan  White          31600      4   970000    4.0   7.3

# %%
car_info_shuffle = car_info.sample(frac=1)
car_info_shuffle
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel
# 4  nissan  White         213095      4   350000    3.0   5.6
# 5  toyota  Green          99213      4   450000    4.0   5.4
# 8  toyota  White          60000      4   625000    4.0   4.7
# 1   honda    Red          87899      4   500000    3.0   5.3
# 6   honda   Blue          45698      4   750000    4.0   4.9
# 2  toyota   Blue          32549      3   700000    4.0   4.2
# 3     bmw  Black          11179      5  2200000    2.0   4.5
# 9  nissan  White          31600      4   970000    4.0   7.3
# 7   honda   Blue          54738      4   700000    4.0   6.8
# 0  toyota  White         150043      4   400000    2.0   5.7

# %%
car_info_shuffle.reset_index(drop=True)
car_info_shuffle
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel
# 0  nissan  White         213095      4   350000    3.0   5.6
# 1  toyota  Green          99213      4   450000    4.0   5.4
# 2  toyota  White          60000      4   625000    4.0   4.7
# 3   honda    Red          87899      4   500000    3.0   5.3
# 4   honda   Blue          45698      4   750000    4.0   4.9
# 5  toyota   Blue          32549      3   700000    4.0   4.2
# 6     bmw  Black          11179      5  2200000    2.0   4.5
# 7  nissan  White          31600      4   970000    4.0   7.3
# 8   honda   Blue          54738      4   700000    4.0   6.8
# 9  toyota  White         150043      4   400000    2.0   5.7

# %%
# Out:
# C:\Users\student.ASTRUM-DOMAIN\AppData\Local\Temp\ipykernel_13244\681487760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_info[car_info['Price'] >= 500000]['Expensive'] = "Good"
